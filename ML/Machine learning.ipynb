# %%
import numpy as np
import pandas as pd
import sklearn

# %%
print("🤖 Machine Learning workspace initialized successfully!")
print("✨ Google Colab connection test to GitHub repository is working!")
# Out:
# 🤖 Machine Learning workspace initialized successfully!
# ✨ Google Colab connection test to GitHub repository is working!
